# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
price_earnings_ratio = pd.read_csv('../datasets/price_earnings_eng_cym_wrangled.csv')
price_earnings_ratio
# Out:
#           Code                      Name        Year  Median_price  \
# 0    K04000001         England and Wales  1997-01-01       59950.0
# 1    E92000001                  England   1997-01-01       59995.0
# 2    E12000001                North East  1997-01-01       46500.0
# 3    E12000002                North West  1997-01-01       48500.0
# 4    E12000003  Yorkshire and The Humber  1997-01-01       48500.0
# ..         ...                       ...         ...           ...
# 307  E12000006                      East  2022-01-01      328000.0
# 308  E12000007                    London  2022-01-01      525000.0
# 309  E12000008                South East  2022-01-01      370000.0
# 310  E12000009                South West  2022-01-01      295000.0
# 311  W92000004                     Wales  2022-01-01      190000.0
#
#      Low_q_Median_price  Median_earning  Low_q_Median_earning  \
# 0               42500.0           16885                 12016
# ...

# %%
extract = pd.DataFrame(price_earnings_ratio)
extract = extract[extract['Code'].isin(['E92000001', 'W92000004'])]
df = extract[['Name', 'Year', 'price_to_earning', 'Low_q_price_to_earning']]

# %%
df = df.sort_values(by=['Name', 'Year']).reset_index(drop=True)

# %%
df
# Out:
#         Name        Year  price_to_earning  Low_q_price_to_earning
# 0   England   1997-01-01              3.54                    3.57
# 1   England   1998-01-01              3.67                    3.57
# 2   England   1999-01-01              3.96                    3.77
# 3   England   2000-01-01              4.19                    3.85
# 4   England   2001-01-01              4.50                    4.08
# 5   England   2002-01-01              5.12                    4.51
# 6   England   2003-01-01              5.93                    5.21
# 7   England   2004-01-01              6.60                    6.27
# 8   England   2005-01-01              6.79                    6.82
# 9   England   2006-01-01              6.95                    7.17
# 10  England   2007-01-01              7.15                    7.21
# 11  England   2008-01-01              6.97                    6.91
# 12  England   2009-01-01              6.40                    6.48
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    52 non-null     object
#  1   Year                    52 non-null     object
#  2   price_to_earning        52 non-null     float64
#  3   Low_q_price_to_earning  52 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.8+ KB

# %%
df.describe()
# Out:
#        price_to_earning  Low_q_price_to_earning
# count         52.000000               52.000000
# mean           5.890000                5.677692
# std            1.499286                1.406936
# min            3.000000                3.100000
# 25%            5.352500                4.945000
# 50%            5.925000                5.735000
# 75%            6.812500                6.830000
# max            9.060000                8.150000

# %%
plt.figure(figsize=(14,7))
plt.title('Trend of Price to Earning Ratio Over Time (Median)')
plt.xlabel('Year')
plt.ylabel('Price to Earning Ratio')
plt.grid(True)

df['Year'] = pd.to_datetime(df['Year'])
df['Plot_Year'] = df['Year'].dt.year
years = df['Plot_Year'].unique()

for name, group in df.groupby('Name'):
    plt.plot(group['Plot_Year'], group['price_to_earning'], label=name)
    plt.plot(group['Plot_Year'], group['Low_q_price_to_earning'],
             label=f'{name} - Lower 25%', linestyle='--')

plt.legend()
plt.show()
